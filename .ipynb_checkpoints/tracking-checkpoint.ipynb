# %%
import cv2
import os
import time

# Create a VideoCapture object
cap = cv2.VideoCapture(0)
cnt = 0
frame_loss_count = 0  # Track invalid frames
start_time = time.time()  # Track script runtime

# Check if the camera opened successfully
if not cap.isOpened():
    print("Error: Unable to open video stream.")
    exit()

# Create 'frames' directory if it doesn't exist
if not os.path.exists("frames"):
    os.makedirs("frames")

while True:
    ret, frame = cap.read()
    
    if not ret or frame is None:
        frame_loss_count += 1
        print(f"Warning: No valid frame received ({frame_loss_count} times).")
        
        # If 10 consecutive invalid frames occur, exit
        if frame_loss_count >= 10:
            print("Error: Too many invalid frames. Exiting...")
            break
        continue  # Skip this loop iteration
    
    # Reset frame loss counter when a valid frame is received
    frame_loss_count = 0

    # Display the normal image without cropping
    cv2.imshow("image", frame)

    # Save frame to 'frames/' directory
    cv2.imwrite(f'frames/{cnt}.png', frame)
    cnt += 1

    # Press 'q' to exit
    key = cv2.waitKey(10)  # Wait 10ms for user input
    if key == ord('q'):
        print("Exit key detected. Closing...")
        break

    # Stop if script runs longer than 5 minutes
    if time.time() - start_time > 15:
        print("Timeout reached. Exiting...")
        break

# Release the video capture and close windows
cap.release()
cv2.destroyAllWindows()
print("Video stream closed successfully.")
# Out:
# Timeout reached. Exiting...
# Video stream closed successfully.

# %%
import cv2
import os

# Path to the input video
video_path = r'C:\Users\ASHUTOSH TIWARI\Downloads\28.mp4'

# Folder to save frames
output_folder = r'C:\Users\ASHUTOSH TIWARI\Downloads\frames'
os.makedirs(output_folder, exist_ok=True)  # Create folder if it doesn't exist

# Open the video file
cap = cv2.VideoCapture(video_path)

# Check if the video opened correctly
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

frame_count = 0

while True:
    ret, frame = cap.read()  # Read a frame

    if not ret:
        break  # Break if no frame is read (end of video)

    frame_filename = os.path.join(output_folder, f'frame_{frame_count:04d}.jpg')
    cv2.imwrite(frame_filename, frame)  # Save the frame as an image

    print(f"Saved {frame_filename}")
    frame_count += 1

# Release video capture and close windows
cap.release()
cv2.destroyAllWindows()

print("Frame extraction complete!")
# Out:
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0000.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0001.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0002.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0003.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0004.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0005.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0006.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0007.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0008.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0009.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0010.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0011.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0012.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0013.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0014.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0015.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0016.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0017.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0018.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0019.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0020.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0021.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0022.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0023.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0024.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0025.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0026.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0027.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0028.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0029.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0030.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0031.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0032.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0033.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0034.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0035.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0036.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0037.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0038.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0039.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0040.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0041.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0042.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0043.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0044.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0045.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0046.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0047.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0048.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0049.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0050.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0051.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0052.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0053.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0054.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0055.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0056.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0057.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0058.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0059.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0060.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0061.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0062.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0063.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0064.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0065.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0066.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0067.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0068.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0069.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0070.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0071.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0072.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0073.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0074.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0075.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0076.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0077.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0078.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0079.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0080.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0081.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0082.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0083.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0084.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0085.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0086.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0087.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0088.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0089.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0090.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0091.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0092.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0093.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0094.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0095.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0096.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0097.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0098.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0099.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0100.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0101.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0102.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0103.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0104.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0105.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0106.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0107.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0108.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0109.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0110.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0111.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0112.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0113.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0114.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0115.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0116.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0117.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0118.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0119.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0120.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_
jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0491.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0492.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0493.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0494.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0495.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0496.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0497.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0498.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0499.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0500.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0501.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0502.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0503.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0504.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0505.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0506.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0507.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0508.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0509.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0510.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0511.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0512.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0513.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0514.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0515.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0516.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0517.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0518.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0519.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0520.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0521.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0522.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0523.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0524.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0525.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0526.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0527.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0528.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0529.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0530.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0531.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0532.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0533.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0534.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0535.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0536.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0537.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0538.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0539.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0540.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0541.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0542.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0543.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0544.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0545.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0546.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0547.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0548.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0549.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0550.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0551.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0552.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0553.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0554.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0555.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0556.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0557.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0558.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0559.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0560.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0561.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0562.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0563.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0564.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0565.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0566.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0567.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0568.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0569.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0570.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0571.jpg
# Saved C:\Users\ASHUTOSH TIWARI\Downloads\frames\frame_0572.jpg
# Frame extraction complete!

# %%
import cv2
import numpy as np
import os
import re

# Define the frames directory
frames_dir = r'C:\Users\ASHUTOSH TIWARI\Downloads\project 2\frames'

# Define the output folder to save processed frames
output_folder = r'C:\Users\ASHUTOSH TIWARI\Downloads\project 2\processed_frames'
os.makedirs(output_folder, exist_ok=True)  # Create folder if it doesn't exist

# Check if the directory exists
if not os.path.exists(frames_dir):
    print("Error: The directory does not exist.")
    exit()

# List all frame file names
frames = os.listdir(frames_dir)

# Sort frames numerically
frames.sort(key=lambda f: int(re.sub(r'\D', '', f)) if re.search(r'\d+', f) else float('inf'))

# Initialize variables
images = []
fixed_size = (200, 200)
cnt = 0

# Read and process frames
for i in frames:
    img_path = os.path.join(frames_dir, i)
    
    # Read image
    img = cv2.imread(img_path)
    
    # Check if image is loaded successfully
    if img is None:
        print(f"Warning: Could not read {img_path}")
        continue

    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    img = cv2.GaussianBlur(img, (25, 25), 0)  # Apply Gaussian blur
    img = cv2.resize(img, fixed_size)  # Resize the image

    images.append(img)  # Append to list
    cnt+=1
    # Save the processed image to the output folder
    output_path = os.path.join(output_folder, f'processed_{cnt:04d}.jpg')
    cv2.imwrite(output_path, img)

    # Display the processed image
    cv2.imshow("Processed Image", img)
    key = cv2.waitKey(10)  # Delay for smooth visualization


cv2.destroyAllWindows()  # Close all OpenCV windows

# Convert images list to NumPy array
images = np.array(images)

print(f"Total images processed: {len(images)}")
print(f"Processed images saved in: {output_folder}")
# Out:
# Total images processed: 573
# Processed images saved in: C:\Users\ASHUTOSH TIWARI\Downloads\project 2\processed_frames

# %%
nonzero=[]
for i in range((len(images)-1)):
    
    mask = cv2.absdiff(images[i],images[i+1])
    _ , mask = cv2.threshold(mask, 50, 255, cv2.THRESH_BINARY)
    num = np.count_nonzero((mask.ravel()))
    nonzero.append(num)
    
    
x = np.arange(0,len(images)-1)
y = nonzero

plt.figure(figsize=(20,4))
plt.scatter(x,y)

# %% [markdown]
# ## Code working correctly till this point

# %%
scene_change_idx=0
threshold = 15 * 10e3
for i in range(len(images)-1):
    if(nonzero[i]>threshold): 
        scene_change_idx = i
        break 
frames = frames[:(scene_change_idx + 1)]

# %%
img= cv2.imread('frames/' + frames[10])
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.GaussianBlur(gray,(25,25),0)

plt.figure(figsize=(5,10))
plt.imshow(gray,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [16], in <module>
# ----> 1 img= cv2.imread('frames/' + frames[10])
#       2 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       3 gray = cv2.GaussianBlur(gray,(25,25),0)
#
# IndexError: list index out of range

# %%
_ , mask = cv2.threshold(gray, 200, 255, cv2.THRESH_BINARY)

plt.figure(figsize=(5,5))
plt.imshow(mask,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-affbd86f33f1> in <module>
# ----> 1 _ , mask = cv2.threshold(gray, 200, 255, cv2.THRESH_BINARY)
#       2
#       3 plt.figure(figsize=(5,5))
#       4 plt.imshow(mask,cmap='gray')
#
# NameError: name 'gray' is not defined

# %%
image, contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-aff36a5895e5> in <module>
# ----> 1 image, contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
#
# NameError: name 'mask' is not defined

# %%
img_copy = np.copy(gray)
cv2.drawContours(img_copy, contours, -1, (0,255,0), 3)
plt.imshow(img_copy, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-73673067fb88> in <module>
# ----> 1 img_copy = np.copy(gray)
#       2 cv2.drawContours(img_copy, contours, -1, (0,255,0), 3)
#       3 plt.imshow(img_copy, cmap='gray')
#
# NameError: name 'gray' is not defined

# %%
# !rm -r patch/*

num=20
cnt=0
for i in range(len(contours)):
    x,y,w,h = cv2.boundingRect(contours[i])
    
    numer=min([w,h])
    denom=max([w,h])
    ratio=numer/denom

    if(x>=num and y>=num):
        xmin, ymin= x-num, y-num
        xmax, ymax= x+w+num, y+h+num
    else:
        xmin, ymin=x, y
        xmax, ymax=x+w, y+h

    if(ratio>=0.5 and ((w<=10) and (h<=10)) ):    
        print(cnt,x,y,w,h,ratio)
        cv2.imwrite("patch/"+str(cnt)+".png",img[ymin:ymax,xmin:xmax])
        cnt=cnt+1
# Out:
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-76cc9b93ad4b> in <module>
#       3 num=20
#       4 cnt=0
# ----> 5 for i in range(len(contours)):
#       6     x,y,w,h = cv2.boundingRect(contours[i])
#       7
#
# NameError: name 'contours' is not defined

# %%
import os
import cv2
import numpy as np
import pandas as pd
folders=os.listdir('data/')

images=[]
labels= []
for folder in folders:
    files=os.listdir('data/'+folder)
    for file in files:
        img=cv2.imread('data/'+folder+'/'+file,0)
        img=cv2.resize(img,(25,25))
          images.append(img)
        labels.append(int(folder))

images = np.array(images)
features = images.reshape(len(images),-1)

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val = train_test_split(features,labels, test_size=0.2, stratify=labels,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier 
rfc = RandomForestClassifier(max_depth=3) 
rfc.fit(x_tr,y_tr)

# %%
from sklearn.metrics import classification_report
y_pred = rfc.predict(x_val)
print(classification_report(y_val,y_pred))

# %%
# !rm -r ball/*
ball_df = pd.DataFrame(columns=['frame','x','y','w','h'])

for idx in range(len(frames)):
    
    img= cv2.imread('frames/' + frames[idx])
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray,(25, 25),0)
    _ , mask = cv2.threshold(gray, 200, 255, cv2.THRESH_BINARY)
    image, contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    
    # !rm -r patch/*

    num=20
    cnt=0
    df = pd.DataFrame(columns=['frame','x','y','w','h'])
    for i in range(len(contours)):
        x,y,w,h = cv2.boundingRect(contours[i])

        numer=min([w,h])
        denom=max([w,h])
        ratio=numer/denom

        if(x>=num and y>=num):
            xmin, ymin= x-num, y-num
            xmax, ymax= x+w+num, y+h+num
        else:
            xmin, ymin= x,y
             xmax, ymax= x+w, y+h

        if(ratio>=0.5):    
            #print(cnt,x,y,w,h,ratio)
            df.loc[cnt,'frame'] = frames[idx]
            df.loc[cnt,'x']=x
            df.loc[cnt,'y']=y
            df.loc[cnt,'w']=w
            df.loc[cnt,'h']=h
            
            cv2.imwrite("patch/"+str(cnt)+".png",img[ymin:ymax,xmin:xmax])
            cnt=cnt+1
              files=os.listdir('patch/')    
    if(len(files)>0):
    
        files.sort(key=lambda f: int(re.sub('\D', '', f)))

        test=[]
        for file in files:
            img=cv2.imread('patch/'+file,0)
            img=cv2.resize(img,(25,25))
            test.append(img)

        test = np.array(test)
        test = test.reshape(len(test),-1)
        y_pred = rfc.predict(test)
        prob=rfc.predict_proba(test)

        if 0 in y_pred:
            ind = np.where(y_pred==0)[0]
            proba = prob[:,0]
            confidence = proba[ind]
            confidence = [i for i in confidence if i>0.7]
            if(len(confidence)>0):

                maximum = max(confidence)
                ball_file=files[list(proba).index(maximum)]
                test = test.reshape(len(test),-1)
        y_pred = rfc.predict(test)
        prob=rfc.predict_proba(test)

        if 0 in y_pred:
            ind = np.where(y_pred==0)[0]
            proba = prob[:,0]
            confidence = proba[ind]
            confidence = [i for i in confidence if i>0.7]
            if(len(confidence)>0):

                maximum = max(confidence)
                ball_file=files[list(proba).index(maximum)]
                
                
                img= cv2.imread('patch/'+ball_file)
                cv2.imwrite('ball/'+str(frames[idx]),img)

                no = int(ball_file.split(".")[0])
                ball_df.loc[idx]= df.loc[no]
        else:
                ball_df.loc[idx,'frame']=frames[idx]

    else:
            ball_df.loc[idx,'frame']=frames[idx]

# %%
ball_df.dropna(inplace=True)
print(ball_df)

# %%
files = ball_df['frame'].values

num=10
for idx in range(len(files)):
    
    #draw contours 
    img = cv2.imread('frames/'+files[idx])
    
    x=ball_df.loc[idx,'x']
    y=ball_df.loc[idx,'y']
    w=ball_df.loc[idx,'w']
    h=ball_df.loc[idx,'h']
    
    xmin=x-num
    ymin=y-num
    xmax=x+w+num
    ymax=y+h+num
    cv2.rectangle(img, (xmin, ymin), (xmax, ymax), (255,0,0), 2)
    cv2.imwrite("frames/"+files[idx],img)

# %%
frames = os.listdir('frames/')
frames.sort(key=lambda f: int(re.sub('\D', '', f)))

frame_array=[]

for i in range(len(frames)):
    #reading each files
    img = cv2.imread('frames/'+frames[i])
    height, width, layers = img.shape
    size = (width,height)
    #inserting the frames into an image array
    frame_array.append(img)

out = cv2.VideoWriter('28.mp4',cv2.VideoWriter_fourcc(*'DIVX'), 25, size)
 for i in range(len(frame_array)):
    # writing to a image array
    out.write(frame_array[i])
out.release()

# %%
# !pip install imutils
# Out:
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25870 sha256=b93a625ab98140ca0394b9182c8298eff4fd2f382bfa84b513467579e5bb274c
#   Stored in directory: c:\users\ashutosh tiwari\appdata\local\pip\cache\wheels\4b\a5\2d\4a070a801d3a3d93f033d3ee9728f470f514826e89952df3ea
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
